# %% [markdown]
# <a href="https://colab.research.google.com/github/ShrimantiGawande/python_programming/blob/main/python2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#support vector machine
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC

#creating a data
x = np.array([[1,2],[2,3],[3,3],[6,5],[7,8],[8,8]])
y=np.array([0,0,0,1,1,1])

#plot raw data
plt.scatter(x[:,0],x[:,1],c=y)
plt.xlabel ("feature 1")
plt.ylabel ("feature 2")
plt.title ("training data")
plt.show ()

#train SVM model
model = SVC (kernel="linear", C=1)
model.fit(x,y)

#define limits (IMPT)
x_min, x_max = x[:,0].min () -1, x[:,1].max () +1
y_min, y_max = x[:,0].min () -1, x[:,1].max () +1

#creating a mesg grid
xx, yy = np.meshgrid(np.linspace (x_min, x_max, 200), np.linspace (y_min, y_max, 200))

#predict grid points
z=model.predict(np.c_[xx.ravel(), yy.ravel()])
z=z.reshape (xx.shape)

#data visualization
plt.contourf (xx,yy,z, alpha = 0.3)
plt.scatter (x[:,0], x[:,1], c=y, edgecolors="k")
plt.xlabel ("feature 1")
plt.ylabel ("feature 2")
plt.title ("SVM decision boundary")
plt.show ()
